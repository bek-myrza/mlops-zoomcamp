# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
import pickle

# %%
import mlflow
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='/workspaces/mlops-zoomcamp/02-experiment-tracking/mlruns/1', creation_time=1716971755359, experiment_id='1', last_update_time=1716971755359, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)
    
    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds()/60)
    
    df = df[(df.duration >= 1) & (df.duration <= 60)]
    
    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2021-01.parquet')

# %%
df_val = read_dataframe('./data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] # ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)
mean_squared_error(y_val, y_pred, squared=False)
# Out:
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 7.758715209663881

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():
    
    mlflow.set_tag("developer", "bek")
    
    mlflow.log_param("train_data_path", "./data/green_tripdata_2021-01.parquet")
    mlflow.log_param("val_data_path", "./data/green_tripdata_2021-02.parquet")

    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha=alpha)
    lr.fit(X_train, y_train)
    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)
# Out:
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
lr = Ridge()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_val)
mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 11.342603943250333

# %%
import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0), # exp(-3), exp(0) - [0.05.1]
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
#   0%|                                                                 | 0/50 [00:00<?, ?trial/s, best loss=?]
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [09:52:31] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:11.41919
# [1]	validation-rmse:10.72811
# [2]	validation-rmse:10.12925
# [3]	validation-rmse:9.61207
# [4]	validation-rmse:9.16755
# [5]	validation-rmse:8.78614
# [6]	validation-rmse:8.46083
# [7]	validation-rmse:8.18405
# [8]	validation-rmse:7.94968
# [9]	validation-rmse:7.75078
# [10]	validation-rmse:7.58236
# [11]	validation-rmse:7.44029
# [12]	validation-rmse:7.32095
# [13]	validation-rmse:7.21997
# [14]	validation-rmse:7.13424
# [15]	validation-rmse:7.06200
# [16]	validation-rmse:6.99963
# [17]	validation-rmse:6.94671
# [18]	validation-rmse:6.90188
# [19]	validation-rmse:6.86376
# [20]	validation-rmse:6.83107
# [21]	validation-rmse:6.80396
# [22]	validation-rmse:6.77995
# [23]	validation-rmse:6.75883
# [24]	validation-rmse:6.74066
# [25]	validation-rmse:6.72442
# [26]	validation-rmse:6.71013
# [27]	validation-rmse:6.69823
# [28]	validation-rmse:6.68734
# [29]	validation-rmse:6.67745
# [30]	validation-rmse:6.66933
# [31]	validation-rmse:6.66176
# [32]	validation-rmse:6.65453
# [33]	validation-rmse:6.64876
# [34]	validation-rmse:6.64292
# [35]	validation-rmse:6.63830
# [36]	validation-rmse:6.63382
# [37]	validation-rmse:6.62969
# [38]	validation-rmse:6.62578
# [39]	validation-rmse:6.62225
# [40]	validation-rmse:6.61841
# [41]	validation-rmse:6.61541
# [42]	validation-rmse:6.61239
# [43]	validation-rmse:6.60931
# [44]	validation-rmse:6.60569
# [45]	validation-rmse:6.60258
# [46]	validation-rmse:6.60016
# [47]	validation-rmse:6.59822
# [48]	validation-rmse:6.59587
# [49]	validation-rmse:6.59384
# [50]	validation-rmse:6.59253
# [51]	validation-rmse:6.59112
# [52]	validation-rmse:6.58955
# [53]	validation-rmse:6.58818
# [54]	validation-rmse:6.58731
# [55]	validation-rmse:6.58653
# [56]	validation-rmse:6.58556
# [57]	validation-rmse:6.58429
# [58]	validation-rmse:6.58360
# [59]	validation-rmse:6.58303
# [60]	validation-rmse:6.58260
# [61]	validation-rmse:6.58185
# [62]	validation-rmse:6.58121
# [63]	validation-rmse:6.58033
# [64]	validation-rmse:6.57975
# [65]	validation-rmse:6.57903
# [66]	validation-rmse:6.57854
# [67]	validation-rmse:6.57768
# [68]	validation-rmse:6.57705
# [69]	validation-rmse:6.57640
# [70]	validation-rmse:6.57593
# [71]	validation-rmse:6.57531
# [72]	validation-rmse:6.57488
# [73]	validation-rmse:6.57447
# [74]	validation-rmse:6.57393
# [75]	validation-rmse:6.57350
# [76]	validation-rmse:6.57275
# [77]	validation-rmse:6.57239
# [78]	validation-rmse:6.57189
# [79]	validation-rmse:6.57152
# [80]	validation-rmse:6.57020
# [81]	validation-rmse:6.56990
# [82]	validation-rmse:6.56868
# [83]	validation-rmse:6.56828
# [84]	validation-rmse:6.56761
# [85]	validation-rmse:6.56721
# [86]	validation-rmse:6.56642
# [87]	validation-rmse:6.56608
# [88]	validation-rmse:6.56554
# [89]	validation-rmse:6.56469
# [90]	validation-rmse:6.56395
# [91]	validation-rmse:6.56354
# [92]	validation-rmse:6.56319
# [93]	validation-rmse:6.56252
# [94]	validation-rmse:6.56231
# [95]	validation-rmse:6.56189
# [96]	validation-rmse:6.56144
# [97]	validation-rmse:6.56123
# [98]	validation-rmse:6.56072
# [99]	validation-rmse:6.56048
# [100]	validation-rmse:6.56018
# [101]	validation-rmse:6.55966
# [102]	validation-rmse:6.55947
# [103]	validation-rmse:6.55906
# [104]	validation-rmse:6.55868
# [105]	validation-rmse:6.55834
# [106]	validation-rmse:6.55827
# [107]	validation-rmse:6.55781
# [108]	validation-rmse:6.55756
# [109]	validation-rmse:6.55720
# [110]	validation-rmse:6.55704
# [111]	validation-rmse:6.55677
# [112]	validation-rmse:6.55657
# [113]	validation-rmse:6.55645
# [114]	validation-rmse:6.55626
# [115]	validation-rmse:6.55602
# [116]	validation-rmse:6.55574
# [117]	validation-rmse:6.55555
# [118]	validation-rmse:6.55529
# [119]	validation-rmse:6.55498
# [120]	validation-rmse:6.55467
# [121]	validation-rmse:6.55445
# [122]	validation-rmse:6.55431
# [123]	validation-rmse:6.55418
# [124]	validation-rmse:6.55386
# [125]	validation-rmse:6.55341
# [126]	validation-rmse:6.55333
# [127]	validation-rmse:6.55302
# [128]	validation-rmse:6.55268
# [129]	validation-rmse:6.55258
# [130]	validation-rmse:6.55238
# [131]	validation-rmse:6.55212
# [132]	validation-rmse:6.55172
# [133]	validation-rmse:6.55156
# [134]	validation-rmse:6.55135
# [135]	validation-rmse:6.55119
# [136]	validation-rmse:6.55103
# [137]	validation-rmse:6.55095
# [138]	validation-rmse:6.55075
# [139]	validation-rmse:6.55064
# [140]	validation-rmse:6.55047
# [141]	validation-rmse:6.55040
# [142]	validation-rmse:6.55018
# [143]	validation-rmse:6.55009
# [144]	validation-rmse:6.55002
# [145]	validation-rmse:6.54984
# [146]	validation-rmse:6.54960
# [147]	validation-rmse:6.54961
# [148]	validation-rmse:6.54938
# [149]	validation-rmse:6.54920
# [150]	validation-rmse:6.54896
# [151]	validation-rmse:6.54881
# [152]	validation-rmse:6.54832
# [153]	validation-rmse:6.54814
# [154]	validation-rmse:6.54802
# [155]	validation-rmse:6.54782
# [156]	validation-rmse:6.54753
# [157]	validation-rmse:6.54741
# [158]	validation-rmse:6.54724
# [159]	validation-rmse:6.54712
# [160]	validation-rmse:6.54693
# [161]	validation-rmse:6.54675
# [162]	validation-rmse:6.54660
# [163]	validation-rmse:6.54633
# [164]	validation-rmse:6.54621
# [165]	validation-rmse:6.54615
# [166]	validation-rmse:6.54587
# [167]	validation-rmse:6.54549
# [168]	validation-rmse:6.54545
# [169]	validation-rmse:6.54529
# [170]	validation-rmse:6.54520
# [171]	validation-rmse:6.54485
# [172]	validation-rmse:6.54465
# [173]	validation-rmse:6.54456
# [174]	validation-rmse:6.54427
# [175]	validation-rmse:6.54415
# [176]	validation-rmse:6.54405
# [177]	validation-rmse:6.54383
# [178]	validation-rmse:6.54366
# [179]	validation-rmse:6.54349
# [180]	validation-rmse:6.54340
# [181]	validation-rmse:6.54331
# [182]	validation-rmse:6.54318
# [183]	validation-rmse:6.54288
# [184]	validation-rmse:6.54278
# [185]	validation-rmse:6.54258
# [186]	validation-rmse:6.54251
# [187]	validation-rmse:6.54234
# [188]	validation-rmse:6.54220
# [189]	validation-rmse:6.54209
# [190]	validation-rmse:6.54202
# [191]	validation-rmse:6.54187
# [192]	validation-rmse:6.54184
# [193]	validation-rmse:6.54171
# [194]	validation-rmse:6.54162
# [195]	validation-rmse:6.54155
# [196]	validation-rmse:6.54146
# [197]	validation-rmse:6.54127
# [198]	validation-rmse:6.54113
# [199]	validation-rmse:6.54105
# [200]	validation-rmse:6.54100
# [201]	validation-rmse:6.54083
# [202]	validation-rmse:6.54064
# [203]	validation-rmse:6.54058
# [204]	validation-rmse:6.54048
# [205]	validation-rmse:6.54036
# [206]	validation-rmse:6.54026
# [207]	validation-rmse:6.54004
# [208]	validation-rmse:6.53989
# [209]	validation-rmse:6.53984
# [210]	validation-rmse:6.53964
# [211]	validation-rmse:6.53958
# [212]	validation-rmse:6.53945
# [213]	validation-rmse:6.53922
# [214]	validation-rmse:6.53912
# [215]	validation-rmse:6.53898
# [216]	validation-rmse:6.53889
# [217]	validation-rmse:6.53881
# [218]	validation-rmse:6.53863
# [219]	validation-rmse:6.53855
# [220]	validation-rmse:6.53846
# [221]	validation-rmse:6.53816
# [222]	validation-rmse:6.53810
# [223]	validation-rmse:6.53803
# [224]	validation-rmse:6.53798
# [225]	validation-rmse:6.53790
# [226]	validation-rmse:6.53783
# [227]	validation-rmse:6.53781
# [228]	validation-rmse:6.53773
# [229]	validation-rmse:6.53760
# [230]	validation-rmse:6.53750
# [231]	validation-rmse:6.53742
# [232]	validation-rmse:6.53737
# [233]	validation-rmse:6.53725
# [234]	validation-rmse:6.53708
# [235]	validation-rmse:6.53695
# [236]	validation-rmse:6.53690
# [237]	validation-rmse:6.53667
# [238]	validation-rmse:6.53665
# [239]	validation-rmse:6.53659
# [240]	validation-rmse:6.53647
# [241]	validation-rmse:6.53628
# [242]	validation-rmse:6.53620
# [243]	validation-rmse:6.53617
# [244]	validation-rmse:6.53614
# [245]	validation-rmse:6.53600
# [246]	validation-rmse:6.53597
# [247]	validation-rmse:6.53585
# [248]	validation-rmse:6.53574
# [249]	validation-rmse:6.53564
# [250]	validation-rmse:6.53554
# [251]	validation-rmse:6.53549
# [252]	validation-rmse:6.53547
# [253]	validation-rmse:6.53542
# [254]	validation-rmse:6.53541
# [255]	validation-rmse:6.53539
# [256]	validation-rmse:6.53528
# [257]	validation-rmse:6.53514
# [258]	validation-rmse:6.53492
# [259]	validation-rmse:6.53481
# [260]	validation-rmse:6.53479
# [261]	validation-rmse:6.53472
# [262]	validation-rmse:6.53463
# [263]	validation-rmse:6.53455
# [264]	validation-rmse:6.53446
# [265]	validation-rmse:6.53435
# [266]	validation-rmse:6.53431
# [267]	validation-rmse:6.53419
# [268]	validation-rmse:6.53407
# [269]	validation-rmse:6.53404
# [270]	validation-rmse:6.53395
# [271]	validation-rmse:6.53387
# [272]	validation-rmse:6.53386
# [273]	validation-rmse:6.53370
# [274]	validation-rmse:6.53367
# [275]	validation-rmse:6.53354
# [276]	validation-rmse:6.53338
# [277]	validation-rmse:6.53327
# [278]	validation-rmse:6.53318
# [279]	validation-rmse:6.53316
# [280]	validation-rmse:6.53312
# [281]	validation-rmse:6.53303
# [282]	validation-rmse:6.53299
# [283]	validation-rmse:6.53287
# [284]	validation-rmse:6.53284
# [285]	validation-rmse:6.53282
# [286]	validation-rmse:6.53278
# [287]	validation-rmse:6.53272
# [288]	validation-rmse:6.53268
# [289]	validation-rmse:6.53252
# [290]	validation-rmse:6.53251
# [291]	validation-rmse:6.53244
# [292]	validation-rmse:6.53226
# [293]	validation-rmse:6.53224
# [294]	validation-rmse:6.53224
# [295]	validation-rmse:6.53211
# [296]	validation-rmse:6.53208
# [297]	validation-rmse:6.53192
# [298]	validation-rmse:6.53176
# [299]	validation-rmse:6.53171
# [300]	validation-rmse:6.53168
# [301]	validation-rmse:6.53170
# [302]	validation-rmse:6.53168
# [303]	validation-rmse:6.53162
# [304]	validation-rmse:6.53157
# [305]	validation-rmse:6.53143
# [306]	validation-rmse:6.53143
# [307]	validation-rmse:6.53137
# [308]	validation-rmse:6.53129
# [309]	validation-rmse:6.53120
# [310]	validation-rmse:6.53111
# [311]	validation-rmse:6.53104
# [312]	validation-rmse:6.53106
# [313]	validation-rmse:6.53108
# [314]	validation-rmse:6.53101
# [315]	validation-rmse:6.53097
# [316]	validation-rmse:6.53097
# [317]	validation-rmse:6.53090
# [318]	validation-rmse:6.53080
# [319]	validation-rmse:6.53079
# [320]	validation-rmse:6.53082
# [321]	validation-rmse:6.53084
# [322]	validation-rmse:6.53086
# [323]	validation-rmse:6.53081
# [324]	validation-rmse:6.53078
# [325]	validation-rmse:6.53077
# [326]	validation-rmse:6.53054
# [327]	validation-rmse:6.53052
# [328]	validation-rmse:6.53031
# [329]	validation-rmse:6.53030
# [330]	validation-rmse:6.53028
# [331]	validation-rmse:6.53024
# [332]	validation-rmse:6.53019
# [333]	validation-rmse:6.53017
# [334]	validation-rmse:6.53020
# [335]	validation-rmse:6.52998
# [336]	validation-rmse:6.52995
# [337]	validation-rmse:6.52991
# [338]	validation-rmse:6.52988
# [339]	validation-rmse:6.52987
# [340]	validation-rmse:6.52983
# [341]	validation-rmse:6.52979
# [342]	validation-rmse:6.52976
# [343]	validation-rmse:6.52971
# [344]	validation-rmse:6.52972
# [345]	validation-rmse:6.52965
# [346]	validation-rmse:6.52958
# [347]	validation-rmse:6.52945
# [348]	validation-rmse:6.52938
# [349]	validation-rmse:6.52937
# [350]	validation-rmse:6.52931
# [351]	validation-rmse:6.52927
# [352]	validation-rmse:6.52925
# [353]	validation-rmse:6.52921
# [354]	validation-rmse:6.52916
# [355]	validation-rmse:6.52920
# [356]	validation-rmse:6.52919
# [357]	validation-rmse:6.52913
# [358]	validation-rmse:6.52904
# [359]	validation-rmse:6.52903
# [360]	validation-rmse:6.52896
# [361]	validation-rmse:6.52896
# [362]	validation-rmse:6.52891
# [363]	validation-rmse:6.52890
# [364]	validation-rmse:6.52887
# [365]	validation-rmse:6.52873
# [366]	validation-rmse:6.52867
# [367]	validation-rmse:6.52865
# [368]	validation-rmse:6.52863
# [369]	validation-rmse:6.52858
# [370]	validation-rmse:6.52858
# [371]	validation-rmse:6.52857
# [372]	validation-rmse:6.52848
# [373]	validation-rmse:6.52850
# [374]	validation-rmse:6.52849
# [375]	validation-rmse:6.52850
# [376]	validation-rmse:6.52841
# [377]	validation-rmse:6.52840
# [378]	validation-rmse:6.52845
# [379]	validation-rmse:6.52844
# [380]	validation-rmse:6.52839
# [381]	validation-rmse:6.52835
# [382]	validation-rmse:6.52824
# [383]	validation-rmse:6.52820
# [384]	validation-rmse:6.52815
# [385]	validation-rmse:6.52812
# [386]	validation-rmse:6.52807
# [387]	validation-rmse:6.52795
# [388]	validation-rmse:6.52790
# [389]	validation-rmse:6.52792
# [390]	validation-rmse:6.52799
# [391]	validation-rmse:6.52793
# [392]	validation-rmse:6.52785
# [393]	validation-rmse:6.52788
# [394]	validation-rmse:6.52781
# [395]	validation-rmse:6.52773
# [396]	validation-rmse:6.52768
# [397]	validation-rmse:6.52770
# [398]	validation-rmse:6.52765
# [399]	validation-rmse:6.52758
# [400]	validation-rmse:6.52755
# [401]	validation-rmse:6.52753
# [402]	validation-rmse:6.52757
# [403]	validation-rmse:6.52758
# [404]	validation-rmse:6.52747
# [405]	validation-rmse:6.52749
# [406]	validation-rmse:6.52730
# [407]	validation-rmse:6.52725
# [408]	validation-rmse:6.52723
# [409]	validation-rmse:6.52721
# [410]	validation-rmse:6.52718
# [411]	validation-rmse:6.52717
# [412]	validation-rmse:6.52714
# [413]	validation-rmse:6.52711
# [414]	validation-rmse:6.52700
# [415]	validation-rmse:6.52695
# [416]	validation-rmse:6.52688
# [417]	validation-rmse:6.52690
# [418]	validation-rmse:6.52684
# [419]	validation-rmse:6.52676
# [420]	validation-rmse:6.52682
# [421]	validation-rmse:6.52682
# [422]	validation-rmse:6.52687
# [423]	validation-rmse:6.52686
# [424]	validation-rmse:6.52678
# [425]	validation-rmse:6.52675
# [426]	validation-rmse:6.52666
# [427]	validation-rmse:6.52669
# [428]	validation-rmse:6.52662
# [429]	validation-rmse:6.52656
# [430]	validation-rmse:6.52652
# [431]	validation-rmse:6.52653
# ...
# [949]	validation-rmse:6.61260
# [950]	validation-rmse:6.61261
# [951]	validation-rmse:6.61259
# [952]	validation-rmse:6.61259
# [953]	validation-rmse:6.61258
# [954]	validation-rmse:6.61257
# [955]	validation-rmse:6.61257
# [956]	validation-rmse:6.61247
# [957]	validation-rmse:6.61245
# [958]	validation-rmse:6.61249
# [959]	validation-rmse:6.61246
# [960]	validation-rmse:6.61247
# [961]	validation-rmse:6.61244
# [962]	validation-rmse:6.61243
# [963]	validation-rmse:6.61243
# [964]	validation-rmse:6.61244
# [965]	validation-rmse:6.61225
# [966]	validation-rmse:6.61224
# [967]	validation-rmse:6.61217
# [968]	validation-rmse:6.61214
# [969]	validation-rmse:6.61214
# [970]	validation-rmse:6.61217
# [971]	validation-rmse:6.61215
# [972]	validation-rmse:6.61213
# [973]	validation-rmse:6.61206
# [974]	validation-rmse:6.61207
# [975]	validation-rmse:6.61215
# [976]	validation-rmse:6.61228
# [977]	validation-rmse:6.61226
# [978]	validation-rmse:6.61223
# [979]	validation-rmse:6.61226
# [980]	validation-rmse:6.61226
# [981]	validation-rmse:6.61223
# [982]	validation-rmse:6.61220
# [983]	validation-rmse:6.61219
# [984]	validation-rmse:6.61221
# [985]	validation-rmse:6.61219
# [986]	validation-rmse:6.61220
# [987]	validation-rmse:6.61228
# [988]	validation-rmse:6.61228
# [989]	validation-rmse:6.61226
# [990]	validation-rmse:6.61224
# [991]	validation-rmse:6.61223
# [992]	validation-rmse:6.61214
# [993]	validation-rmse:6.61214
# [994]	validation-rmse:6.61214
# [995]	validation-rmse:6.61214
# [996]	validation-rmse:6.61214
# [997]	validation-rmse:6.61214
# [998]	validation-rmse:6.61212
# [999]	validation-rmse:6.61209
#  16%|█████▉                               | 8/50 [19:18<1:22:06, 117.31s/trial, best loss: 6.333493634063673]
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [10:11:49] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:11.73322
# [1]	validation-rmse:11.28989
# [2]	validation-rmse:10.88080
# [3]	validation-rmse:10.50364
# [4]	validation-rmse:10.15725
# [5]	validation-rmse:9.83842
# [6]	validation-rmse:9.54587
# [7]	validation-rmse:9.27781
# [8]	validation-rmse:9.03224
# [9]	validation-rmse:8.80748
# [10]	validation-rmse:8.60235
# [11]	validation-rmse:8.41531
# [12]	validation-rmse:8.24408
# [13]	validation-rmse:8.08953
# [14]	validation-rmse:7.94770
# [15]	validation-rmse:7.81899
# [16]	validation-rmse:7.70251
# [17]	validation-rmse:7.59674
# [18]	validation-rmse:7.49989
# [19]	validation-rmse:7.41249
# [20]	validation-rmse:7.33348
# [21]	validation-rmse:7.26172
# [22]	validation-rmse:7.19587
# [23]	validation-rmse:7.13624
# [24]	validation-rmse:7.08272
#  16%|█████▉                               | 8/50 [19:51<1:44:15, 148.94s/trial, best loss: 6.333493634063673]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 11
#       1 search_space = {
#       2     'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
#       3     'learning_rate': hp.loguniform('learning_rate', -3, 0), # exp(-3), exp(0) - [0.05.1]
#    (...)
#       8     'seed': 42
#       9 }
# ---> 11 best_result = fmin(
#      12     fn=objective,
#      13     space=search_space,
#      14     algo=tpe.suggest,
#      15     max_evals=50,
#      16     trials=Trials()
#      17 )
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[16], line 5, in objective(params)
#       3 mlflow.set_tag("model", "xgboost")
#       4 mlflow.log_params(params)
# ----> 5 booster = xgb.train(
#       6     params=params,
#       7     dtrain=train,
#       8     num_boost_round=1000,
#       9     evals=[(valid, 'validation')],
#      10     early_stopping_rounds=50
#      11 )
#      12 y_pred = booster.predict(valid)
#      13 rmse = mean_squared_error(y_val, y_pred, squared=False)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:2051, in Booster.update(self, dtrain, iteration, fobj)
#    2047 self._assign_dmatrix_features(dtrain)
#    2049 if fobj is None:
#    2050     _check_call(
# -> 2051         _LIB.XGBoosterUpdateOneIter(
#    2052             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2053         )
#    2054     )
#    2055 else:
#    2056     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
mlflow.xgboost.autolog(disable=True)

# %%
with mlflow.start_run():
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:linear',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
        mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
